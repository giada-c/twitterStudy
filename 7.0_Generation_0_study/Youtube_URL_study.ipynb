# %% [markdown]
# # Youtube URL study

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np

from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, '../4_URL_study')
import url_util as ut
sys.path.insert(0, '../')
import general_utils as gen_ut

# %% [markdown]
# ## Dataset preparation

# %%
df_yt_complete = pd.read_csv('../4_URL_study/Youtube_URL.csv',low_memory=False)
df_yt_complete = df_yt_complete.groupby('url').first().sort_values(by='occurrency',ascending=False)
df_yt_complete.head()
# Out:
#                                                                                          title  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  I LOCKDOWNS: DISTRUGGERANNO PIU' VITE DI QUANT...
# https://www.youtube.com/watch?v=xgfQfDh4puk  DAL TOP DI HARVARD, LE INCOGNITE DI CoV-2, IMM...
# https://www.youtube.com/watch?v=-BbnIlxaqJM  VACCINI OBBLIGATORI AGGRAVEREBBERO LA SITUAZIO...
# https://youtu.be/kHGtn_vnrJ8                 IL PARERE DEL PREMIO NOBEL LUC MONTAGNIER SULL...
# https://youtu.be/GJrC0xAAXoU                                       VACCINO: i dubbi più grossi
#
#                                                                                    description  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  Intervista all'epidemiologa di punta della Har...
# https://www.youtube.com/watch?v=xgfQfDh4puk  David R. Walt della Harvard University Medical...
# https://www.youtube.com/watch?v=-BbnIlxaqJM  ISCRIVITI AL NOSTRO CANALE YOUTUBE: https://bi...
# https://youtu.be/kHGtn_vnrJ8                 - Vi farete vaccinare oggi contro il #Covid?\n...
# https://youtu.be/GJrC0xAAXoU                 Ho cercato di fare da tramite tra gli enti per...
#
#                                                      type  available  reason  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  decompressed       True  Parsed
# https://www.youtube.com/watch?v=xgfQfDh4puk  decompressed       True  Parsed
# https://www.youtube.com/watch?v=-BbnIlxaqJM  decompressed       True  Parsed
# https://youtu.be/kHGtn_vnrJ8                   compressed       True  Parsed
# https://youtu.be/GJrC0xAAXoU                   compressed       True  Parsed
#
#                                              occurrency
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo         508
# https://www.youtube.com/watch?v=xgfQfDh4puk         346
# https://www.youtube.com/watch?v=-BbnIlxaqJM         265
# https://youtu.be/kHGtn_vnrJ8                        192
# https://youtu.be/GJrC0xAAXoU                        165

# %%
df = pd.read_csv('../Tweets.csv',low_memory=False,usecols=['user_screen_name','urls'])
df.head()

# %%
data = pd.read_csv('../1_Dataset_preparation/listControlledUsers.csv')  
listNovax = list(data[data['malicious']].iloc[:,0])
listProvax = list(data[data['benevolent']].iloc[:,0])

# %%
df_novax = df[np.in1d(df['user_screen_name'], listNovax)].copy()
df_provax = df[np.in1d(df['user_screen_name'], listProvax)].copy()

# %% [markdown]
# ## General info about the video shared

# %%
df_yt_summary = df_yt_complete.groupby(['reason']).count()
df_yt_summary
# Out:
#              title  description  type  available  occurrency
# reason
# Error 404        0            0     4          4           4
# Parsed        4856         4347  4857       4857        4857
# Playlist         0            0     2          2           2
# Profile          0            0    44         44          44
# Unavailable      0            0  1729       1729        1729

# %%
plt.figure(figsize=(20,10))
s = df_yt_summary['occurrency'].sum()
plt.pie(df_yt_summary['occurrency'], labels=df_yt_summary.index, shadow=True, startangle=100,
       autopct=lambda p:f'{p:.2f}% ({p*(s)/100 :,.0f})'.replace(',', '\''),
       explode = [0.25,0.0,0.25,0.0,0.0])
plt.show()

# %%
df_yt = df_yt_complete[np.logical_or(df_yt_complete['reason']=='Parsed' , df_yt_complete['reason']=='Unavailable')]
df_yt
# Out:
#                                                                                          title  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  I LOCKDOWNS: DISTRUGGERANNO PIU' VITE DI QUANT...
# https://www.youtube.com/watch?v=xgfQfDh4puk  DAL TOP DI HARVARD, LE INCOGNITE DI CoV-2, IMM...
# https://www.youtube.com/watch?v=-BbnIlxaqJM  VACCINI OBBLIGATORI AGGRAVEREBBERO LA SITUAZIO...
# https://youtu.be/kHGtn_vnrJ8                 IL PARERE DEL PREMIO NOBEL LUC MONTAGNIER SULL...
# https://youtu.be/GJrC0xAAXoU                                       VACCINO: i dubbi più grossi
# ...                                                                                        ...
# https://youtu.be/Ag-wQZvvXkQ                                        Vaccino per le Granfondo ?
# https://youtu.be/Afnq33Ht2O8                            VacciNation, sottotitolato in italiano
# https://youtu.be/AdFUDl4NOSo                                                              None
# https://youtu.be/AawB8fJQjD0                 Coronavirus, chi è guarito è immune dal contag...
# https://youtu.be/AaWd-3Vj2qM                 Mentre la Pandemia imperversa, questa è la sit...
#
#                                                                                    description  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  Intervista all'epidemiologa di punta della Har...
# https://www.youtube.com/watch?v=xgfQfDh4puk  David R. Walt della Harvard University Medical...
# https://www.youtube.com/watch?v=-BbnIlxaqJM  ISCRIVITI AL NOSTRO CANALE YOUTUBE: https://bi...
# https://youtu.be/kHGtn_vnrJ8                 - Vi farete vaccinare oggi contro il #Covid?\n...
# https://youtu.be/GJrC0xAAXoU                 Ho cercato di fare da tramite tra gli enti per...
# ...                                                                                        ...
# https://youtu.be/Ag-wQZvvXkQ                 Vaccino per le Granfondo ?\n➡️Link intervista ...
# https://youtu.be/Afnq33Ht2O8                 La storia di Alan Yurko, condannato ingiustame...
# https://youtu.be/AdFUDl4NOSo                                                              None
# https://youtu.be/AawB8fJQjD0                 Francesco Le Foche (Immunologo Policlinico Umb...
# https://youtu.be/AaWd-3Vj2qM                 In tutto il mondo è esplosa la #pandemia, con ...
#
#                                                      type  available  \
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo  decompressed       True
# https://www.youtube.com/watch?v=xgfQfDh4puk  decompressed       True
# https://www.youtube.com/watch?v=-BbnIlxaqJM  decompressed       True
# https://youtu.be/kHGtn_vnrJ8                   compressed       True
# https://youtu.be/GJrC0xAAXoU                   compressed       True
# ...                                                   ...        ...
# https://youtu.be/Ag-wQZvvXkQ                   compressed       True
# https://youtu.be/Afnq33Ht2O8                   compressed       True
# https://youtu.be/AdFUDl4NOSo                   compressed      False
# https://youtu.be/AawB8fJQjD0                   compressed       True
# https://youtu.be/AaWd-3Vj2qM                   compressed       True
#
#                                                   reason  occurrency
# url
# https://www.youtube.com/watch?v=U-kC9XkT7Eo       Parsed         508
# https://www.youtube.com/watch?v=xgfQfDh4puk       Parsed         346
# https://www.youtube.com/watch?v=-BbnIlxaqJM       Parsed         265
# https://youtu.be/kHGtn_vnrJ8                      Parsed         192
# https://youtu.be/GJrC0xAAXoU                      Parsed         165
# ...                                                  ...         ...
# https://youtu.be/Ag-wQZvvXkQ                      Parsed           1
# https://youtu.be/Afnq33Ht2O8                      Parsed           1
# https://youtu.be/AdFUDl4NOSo                 Unavailable           1
# https://youtu.be/AawB8fJQjD0                      Parsed           1
# https://youtu.be/AaWd-3Vj2qM                      Parsed           1
#
# [6586 rows x 6 columns]

# %% [markdown]
# ## Tracking user with type youtbe video shared
# Done only for unavailbe and parsed video

# %% [markdown]
# ### Novax users

# %%
df_url_novax = df_novax[df_novax['urls'] != '[]'].copy()

df_url_novax = ut.get_dfYt_line(df_url_novax,df_yt.index)
df_url_novax = df_url_novax[df_url_novax['yt']]

df_url_novax
# Out:
#         user_screen_name                                               urls  \
# 1141         IacobellisT  [{'url': 'https://t.co/otlx8DwhOC', 'expanded_...
# 1157         IacobellisT  [{'url': 'https://t.co/bZtBeHU1OQ', 'expanded_...
# 1171          TommyBrain  [{'url': 'https://t.co/Ok58cRZkSK', 'expanded_...
# 1175         IacobellisT  [{'url': 'https://t.co/I6mZ530RLx', 'expanded_...
# 1178          TommyBrain  [{'url': 'https://t.co/lzU0X81GEG', 'expanded_...
# ...                  ...                                                ...
# 4041365     EliseiNicole  [{'url': 'https://t.co/HiR74ZmWST', 'expanded_...
# 4043595  Mariang47614228  [{'url': 'https://t.co/SoYAmhghxw', 'expanded_...
# 4048194       TommyBrain  [{'url': 'https://t.co/4FlUHFjrwD', 'expanded_...
# 4048578      Bluefidel47  [{'url': 'https://t.co/556qwqyDJW', 'expanded_...
# 4049340   marchesaangeli  [{'url': 'https://t.co/2B0A1ekT7G', 'expanded_...
#
#            yt
# 1141     True
# 1157     True
# 1171     True
# 1175     True
# 1178     True
# ...       ...
# 4041365  True
# 4043595  True
# 4048194  True
# 4048578  True
# 4049340  True
#
# [3925 rows x 3 columns]

# %%
df_user_novax_yt = pd.DataFrame(columns=['name','url','type'])

for i in df_url_novax.index:
    user = df_novax.at[i, 'user_screen_name']
    s = df_novax.at[i, 'urls']
    urls = gen_ut.get_string_json(s, 'expanded_url')
    for url in urls:
        if url in df_yt.index:
            df_user_novax_yt.loc[df_user_novax_yt.shape[0]] = [user,url,df_yt.loc[url,'reason']]
            

df_user_novax_yt
# Out:
#                  name                                          url  \
# 0         IacobellisT  https://www.youtube.com/watch?v=xgfQfDh4puk
# 1         IacobellisT  https://www.youtube.com/watch?v=dSs1RSBqVnY
# 2          TommyBrain  https://www.youtube.com/watch?v=U-kC9XkT7Eo
# 3         IacobellisT  https://www.youtube.com/watch?v=U-kC9XkT7Eo
# 4          TommyBrain  https://www.youtube.com/watch?v=xgfQfDh4puk
# ...               ...                                          ...
# 3920     EliseiNicole                 https://youtu.be/HQY_XkFOsSA
# 3921  Mariang47614228                 https://youtu.be/_1KsDNQWrgU
# 3922       TommyBrain  https://www.youtube.com/watch?v=rzYk7-RoTow
# 3923      Bluefidel47                 https://youtu.be/Fck6ZwNiq-w
# 3924   marchesaangeli                 https://youtu.be/eqvFlgydWVw
#
#              type
# 0          Parsed
# 1          Parsed
# 2          Parsed
# 3          Parsed
# 4          Parsed
# ...           ...
# 3920       Parsed
# 3921  Unavailable
# 3922       Parsed
# 3923       Parsed
# 3924       Parsed
#
# [3925 rows x 3 columns]

# %%
df_user_novax_yt['total'] = 1
df_user_novax_yt['isParsed'] = 0
df_user_novax_yt.loc[df_user_novax_yt['type']=='Parsed','isParsed'] = 1


df_user_novax_group = df_user_novax_yt.groupby(['name']).sum().sort_values(['total'],ascending=False)

# %%
plt.figure(figsize=(15,10))
plt.barh(df_user_novax_group.head(20).index,df_user_novax_group.head(20).total,label='Total')
plt.barh(df_user_novax_group.head(20).index,df_user_novax_group.head(20).total-df_user_novax_group.head(20).isParsed
        ,label='Unavailbe')
plt.legend()
plt.title('Number of youtube video shared (malicious)')
# Out:
# Text(0.5, 1.0, 'Number of youtube video shared (malicious)')

# %% [markdown]
# ### Provax users

# %%
df_url_provax = df_provax[df_provax['urls'] != '[]'].copy()

df_url_provax = ut.get_dfYt_line(df_url_provax,df_yt.index)
df_url_provax = df_url_provax[df_url_provax['yt']]

df_url_provax
# Out:
#         user_screen_name                                               urls  \
# 230246       bgallavotti  [{'url': 'https://t.co/8dAA3ZWgwr', 'expanded_...
# 549401    Aifa_ufficiale  [{'url': 'https://t.co/cFzPSMYUgW', 'expanded_...
# 550922    Aifa_ufficiale  [{'url': 'https://t.co/cFzPSMYUgW', 'expanded_...
# 553767    Aifa_ufficiale  [{'url': 'https://t.co/cFzPSMYUgW', 'expanded_...
# 1047612    GiacomoGorini  [{'url': 'https://t.co/fSLi3FULBx', 'expanded_...
# 1214242      ISSalute_it  [{'url': 'https://t.co/PXbcsJK7f5', 'expanded_...
# 1256573   RobertoBurioni  [{'url': 'https://t.co/Qiiqryc6k1', 'expanded_...
# 1345375        istsupsan  [{'url': 'https://t.co/LtQuEVDcJw', 'expanded_...
# 1504998   BiologiScienza  [{'url': 'https://t.co/SxzJwJpljG', 'expanded_...
# 1668830            GIMBE  [{'url': 'https://t.co/Txv5bZWHZK', 'expanded_...
# 1668834    Cartabellotta  [{'url': 'https://t.co/Txv5bZWHZK', 'expanded_...
# 1669158    Cartabellotta  [{'url': 'https://t.co/Txv5bZWHZK', 'expanded_...
# 1726175      bgallavotti  [{'url': 'https://t.co/tWPQ0qsMNz', 'expanded_...
# 1764375   RobertoBurioni  [{'url': 'https://t.co/u9SW8gErEJ', 'expanded_...
# 1970010   BiologiScienza  [{'url': 'https://t.co/GCYMY8uuej', 'expanded_...
# 1973356      bgallavotti  [{'url': 'https://t.co/WeXHP86qEW', 'expanded_...
# 2124590    Cartabellotta  [{'url': 'https://t.co/ynmvalESgG', 'expanded_...
# 2125649            GIMBE  [{'url': 'https://t.co/ynmvalESgG', 'expanded_...
# 2364510      ilariacapua  [{'url': 'https://t.co/rQ7Ko1O7nK', 'expanded_...
# 3187965  MinisteroSalute  [{'url': 'https://t.co/R3J15lJJYp', 'expanded_...
# 3416674  MinisteroSalute  [{'url': 'https://t.co/niMhgYNIV7', 'expanded_...
# 3507643   Aifa_ufficiale  [{'url': 'https://t.co/ahOcNL285o', 'expanded_...
# 3790345  antonellaviol17  [{'url': 'https://t.co/ksP5cGHD1O', 'expanded_...
# 3937205  antonellaviol17  [{'url': 'https://t.co/ZcIQ8XxRnP', 'expanded_...
#
#            yt
# 230246   True
# 549401   True
# 550922   True
# 553767   True
# 1047612  True
# 1214242  True
# 1256573  True
# 1345375  True
# 1504998  True
# 1668830  True
# 1668834  True
# 1669158  True
# 1726175  True
# 1764375  True
# 1970010  True
# 1973356  True
# 2124590  True
# 2125649  True
# 2364510  True
# 3187965  True
# 3416674  True
# 3507643  True
# 3790345  True
# 3937205  True

# %%
df_user_provax_yt = pd.DataFrame(columns=['name','url','type'])

for i in df_url_provax.index:
    user = df_provax.at[i, 'user_screen_name']
    s = df_provax.at[i, 'urls']
    urls = gen_ut.get_string_json(s, 'expanded_url')
    for url in urls:
        if url in df_yt.index:
            df_user_provax_yt.loc[df_user_provax_yt.shape[0]] = [user,url,df_yt.loc[url,'reason']]

# %%
df_user_provax_yt['total'] = 1
df_user_provax_yt['isParsed'] = 0
df_user_provax_yt.loc[df_user_provax_yt['type']=='Parsed','isParsed'] = 1


df_user_provax_group = df_user_provax_yt.groupby(['name']).sum().sort_values(['total'],ascending=False)
df_user_provax_group
# Out:
#                  total  isParsed
# name
# Aifa_ufficiale       4         4
# Cartabellotta        3         1
# bgallavotti          3         3
# BiologiScienza       2         2
# GIMBE                2         1
# MinisteroSalute      2         2
# RobertoBurioni       2         2
# antonellaviol17      2         2
# GiacomoGorini        1         1
# ISSalute_it          1         1
# ilariacapua          1         1
# istsupsan            1         1

# %%
plt.figure(figsize=(15,10))
plt.barh(df_user_provax_group.head(20).index,df_user_provax_group.head(20).total,label='Total')
plt.barh(df_user_provax_group.head(20).index,df_user_provax_group.head(20).total-df_user_provax_group.head(20).isParsed
        ,label='Unavailbe')
plt.legend()
plt.title('Number of youtube video shared (benevolent)')
# Out:
# Text(0.5, 1.0, 'Number of youtube video shared (benevolent)')
